# %%
from IPython.display import Image 
Image("Input-CSV-Document-1.png")

# %%
from IPython.display import Image
Image("26-Merged-table-on-Excel.png")

# %%
from IPython.display import Image
Image("0ce0745-project-json-settings.png")

# %%
# Importing libraries 

import pandas as pd

# %% [markdown]
# ## Reading Data from Excel Files

# %%
# excel absolute file path
excel_file = "Cola.xlsx"

#read data from an excel file 
cola_data = pd.read_excel(excel_file)

#check the first few rows of data loaded from Excel
cola_data.head()
# Out:
#    Data provided by SimFin              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      NaN                     NaN        NaN        NaN
# 1  Profit & Loss statement                     NaN        NaN        NaN
# 2                      NaN          in million USD     FY '09     FY '10
# 3                      NaN  NET OPERATING REVENUES      30990      35119
# 4                      NaN      Cost of goods sold      11088      12693
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2     FY '11     FY '12     FY '13     FY '14     FY '15     FY '16
# 3      46542      48017      46854      45998      44294      41863
# 4      18215      19053      18421      17889      17482      16465
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2      FY '17      FY '18
# ...

# %%
cola_data.tail(3)
# Out:
#     Data provided by SimFin  \
# 100                     NaN
# 101                     NaN
# 102                     NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 100        NaN        NaN        NaN        NaN          0          0
# 101        NaN        NaN        NaN        NaN          0          0
# 102       4286      -4361       1972      -1456      -1649       1246
#
#     Unnamed: 10 Unnamed: 11
# 100         -38         205
# 101          15          91
# 102       -2477        2945

# %%
cola_data = pd.read_excel(excel_file, header = 1)
cola_data
# Out:
#                   Unnamed: 0  \
# 0    Profit & Loss statement
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 97                       NaN
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                       in million USD     FY '09     FY '10
# 2                               NET OPERATING REVENUES      30990      35119
# 3                                   Cost of goods sold      11088      12693
# 4                                         Gross Profit      19902      22426
# ..                                                 ...        ...        ...
# ...

# %%
# use the names parameter to specify the column names explicitly
