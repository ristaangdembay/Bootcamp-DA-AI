# %%
# Importing Libraries
import pandas as pd
import numpy as np

# %%
# Importing data of appointment no show   as .csv file
data = pd.read_csv("KaggleV2-May-2016.csv")

# %%
# printing the first 5 rows of the data using .head() function
data.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
#Getting the columns of the dataset

columns = list(data.columns)
columns
# Out:
# ['PatientId',
#  'AppointmentID',
#  'Gender',
#  'ScheduledDay',
#  'AppointmentDay',
#  'Age',
#  'Neighbourhood',
#  'Scholarship',
#  'Hipertension',
#  'Diabetes',
#  'Alcoholism',
#  'Handcap',
#  'SMS_received',
#  'No-show']

# %%
# Examing missing values 

print("Missing values distribution: ")
print(data.isnull().mean())
print("")
# Out:
# Missing values distribution:
# PatientId         0.0
# AppointmentID     0.0
# Gender            0.0
# ScheduledDay      0.0
# AppointmentDay    0.0
# Age               0.0
# Neighbourhood     0.0
# Scholarship       0.0
# Hipertension      0.0
# Diabetes          0.0
# Alcoholism        0.0
# Handcap           0.0
# SMS_received      0.0
# No-show           0.0
# dtype: float64

# %% [markdown]
# From the output, we can see there is no missing values datasets. But we can add a null column and clean it.

# %%
data1 = data

# %%
data1['Country'] = ""

# %%
data1
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
import random

# %%
data1['randomnum'] = random.sample(range(110527), len(data1))

# %%
data1.head(2)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
#
#          AppointmentDay  Age    Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62  JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56  JARDIM DA PENHA            0             0
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show Country  randomnum
# 0         0           0        0             0      No             100422
# 1         0           0        0             0      No              77200

# %%
#check datatype in each coulmn
print("Column datatypes: ")
print(data.dtypes)
# Out:
# Column datatypes:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# Country            object
# randomnum           int64
# dtype: object

# %% [markdown]
# Check for trailing whitespaces for the columns of strings

# %%
# getting all the columns with string/mixed type values
str_cols = []

for str in data.columns:
    if 


#remove leading and trailing characters from columns with str type
for i in str_cols:
    data[i] = data[i].str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/208424471.py in <module>
#       5 #remove leading and trailing characters from columns with str type
#       6 for i in str_cols:
# ----> 7     data[i] = data[i].str.strip()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...
